# %%
import numpy as np
import pandas as pd

# %%
def normalize(data):
    return (data - data.min(axis=0)) / (data.max(axis=0) - data.min(axis=0))

# %%
def calculate_entropy(data):
    P = data / data.sum(axis=0)
    E = -np.nansum(P * np.log(P), axis=0) / np.log(data.shape[0])
    return E

# %%
def calculate_weights(entropy):
    return (1 - entropy) / (1 - entropy).sum()

# %%
def weighted_sum(data, weights):
    return np.dot(data, weights)

# %%
path = r"C:/Users/海棠微雨/Desktop/cumcm2021c/C/附件1 近5年402家供应商的相关数据.xlsx"
df = pd.read_excel(path, sheet_name='供应商的供货量（m³）')

# 提取供应商名称和数据
suppliers = df.iloc[:, 0].values
data = df.iloc[:, 2:].values

# %%
# 标准化数据
normalized_data = normalize(data)

# 计算熵值
entropy = calculate_entropy(normalized_data)

# 计算权重
weights = calculate_weights(entropy)

# 计算每行的综合评价得分
scores = weighted_sum(normalized_data, weights)


# 获取评分排名的结果
indices = np.argsort(scores)[::-1][:]
scores = scores[indices]
suppliers = suppliers[indices]

for i, (supplier, score) in enumerate(zip(suppliers, scores)):
    print(f"排名第{i+1}的供应商: {supplier}, 综合评价得分: {score:.4f}")
# Out:
# 排名第1的供应商: S050, 综合评价得分: 0.6221
# 排名第2的供应商: S111, 综合评价得分: 0.5774
# 排名第3的供应商: S163, 综合评价得分: 0.3618
# 排名第4的供应商: S160, 综合评价得分: 0.3320
# 排名第5的供应商: S153, 综合评价得分: 0.3079
# 排名第6的供应商: S013, 综合评价得分: 0.2827
# 排名第7的供应商: S190, 综合评价得分: 0.2788
# 排名第8的供应商: S102, 综合评价得分: 0.2761
# 排名第9的供应商: S137, 综合评价得分: 0.2503
# 排名第10的供应商: S334, 综合评价得分: 0.2477
# 排名第11的供应商: S355, 综合评价得分: 0.2348
# 排名第12的供应商: S281, 综合评价得分: 0.2335
# 排名第13的供应商: S085, 综合评价得分: 0.2302
# 排名第14的供应商: S354, 综合评价得分: 0.2292
# 排名第15的供应商: S117, 综合评价得分: 0.1808
# 排名第16的供应商: S328, 综合评价得分: 0.1631
# 排名第17的供应商: S336, 综合评价得分: 0.1487
# 排名第18的供应商: S296, 综合评价得分: 0.1010
# 排名第19的供应商: S090, 综合评价得分: 0.1005
# 排名第20的供应商: S217, 综合评价得分: 0.0887
# 排名第21的供应商: S080, 综合评价得分: 0.0840
# 排名第22的供应商: S402, 综合评价得分: 0.0831
# 排名第23的供应商: S020, 综合评价得分: 0.0805
# 排名第24的供应商: S128, 综合评价得分: 0.0804
# 排名第25的供应商: S309, 综合评价得分: 0.0770
# 排名第26的供应商: S364, 综合评价得分: 0.0738
# 排名第27的供应商: S223, 综合评价得分: 0.0699
# 排名第28的供应商: S378, 综合评价得分: 0.0573
# 排名第29的供应商: S374, 综合评价得分: 0.0552
# 排名第30的供应商: S069, 综合评价得分: 0.0539
# 排名第31的供应商: S251, 综合评价得分: 0.0489
# 排名第32的供应商: S083, 综合评价得分: 0.0449
# 排名第33的供应商: S255, 综合评价得分: 0.0414
# 排名第34的供应商: S109, 综合评价得分: 0.0406
# 排名第35的供应商: S349, 综合评价得分: 0.0339
# 排名第36的供应商: S086, 综合评价得分: 0.0331
# 排名第37的供应商: S245, 综合评价得分: 0.0320
# 排名第38的供应商: S243, 综合评价得分: 0.0317
# 排名第39的供应商: S185, 综合评价得分: 0.0314
# 排名第40的供应商: S231, 综合评价得分: 0.0261
# 排名第41的供应商: S249, 综合评价得分: 0.0258
# 排名第42的供应商: S108, 综合评价得分: 0.0257
# 排名第43的供应商: S335, 综合评价得分: 0.0223
# 排名第44的供应商: S258, 综合评价得分: 0.0209
# 排名第45的供应商: S138, 综合评价得分: 0.0169
# 排名第46的供应商: S253, 综合评价得分: 0.0166
# 排名第47的供应商: S320, 综合评价得分: 0.0156
# 排名第48的供应商: S303, 综合评价得分: 0.0153
# 排名第49的供应商: S112, 综合评价得分: 0.0153
# 排名第50的供应商: S265, 综合评价得分: 0.0150
# 排名第51的供应商: S340, 综合评价得分: 0.0131
# 排名第52的供应商: S299, 综合评价得分: 0.0117
# 排名第53的供应商: S046, 综合评价得分: 0.0116
# 排名第54的供应商: S329, 综合评价得分: 0.0112
# 排名第55的供应商: S092, 综合评价得分: 0.0106
# 排名第56的供应商: S176, 综合评价得分: 0.0060
# 排名第57的供应商: S201, 综合评价得分: 0.0036
# 排名第58的供应商: S121, 综合评价得分: 0.0035
# 排名第59的供应商: S049, 综合评价得分: 0.0030
# 排名第60的供应商: S030, 综合评价得分: 0.0014
# 排名第61的供应商: S007, 综合评价得分: 0.0008
# 排名第62的供应商: S011, 综合评价得分: 0.0008
# 排名第63的供应商: S008, 综合评价得分: 0.0008
# 排名第64的供应商: S210, 综合评价得分: 0.0008
# 排名第65的供应商: S390, 综合评价得分: 0.0008
# 排名第66的供应商: S369, 综合评价得分: 0.0007
# 排名第67的供应商: S066, 综合评价得分: 0.0007
# 排名第68的供应商: S119, 综合评价得分: 0.0007
# 排名第69的供应商: S376, 综合评价得分: 0.0007
# 排名第70的供应商: S373, 综合评价得分: 0.0007
# 排名第71的供应商: S205, 综合评价得分: 0.0007
# 排名第72的供应商: S297, 综合评价得分: 0.0007
# 排名第73的供应商: S381, 综合评价得分: 0.0007
# 排名第74的供应商: S101, 综合评价得分: 0.0007
# 排名第75的供应商: S391, 综合评价得分: 0.0007
# 排名第76的供应商: S380, 综合评价得分: 0.0007
# 排名第77的供应商: S358, 综合评价得分: 0.0007
# 排名第78的供应商: S304, 综合评价得分: 0.0007
# 排名第79的供应商: S159, 综合评价得分: 0.0007
# 排名第80的供应商: S097, 综合评价得分: 0.0007
# 排名第81的供应商: S036, 综合评价得分: 0.0007
# 排名第82的供应商: S042, 综合评价得分: 0.0007
# 排名第83的供应商: S396, 综合评价得分: 0.0007
# 排名第84的供应商: S142, 综合评价得分: 0.0007
# 排名第85的供应商: S048, 综合评价得分: 0.0007
# 排名第86的供应商: S076, 综合评价得分: 0.0007
# 排名第87的供应商: S216, 综合评价得分: 0.0007
# 排名第88的供应商: S141, 综合评价得分: 0.0007
# 排名第89的供应商: S053, 综合评价得分: 0.0007
# 排名第90的供应商: S312, 综合评价得分: 0.0006
# 排名第91的供应商: S067, 综合评价得分: 0.0006
# 排名第92的供应商: S239, 综合评价得分: 0.0006
# 排名第93的供应商: S347, 综合评价得分: 0.0006
# 排名第94的供应商: S039, 综合评价得分: 0.0006
# 排名第95的供应商: S224, 综合评价得分: 0.0006
# 排名第96的供应商: S348, 综合评价得分: 0.0006
# 排名第97的供应商: S325, 综合评价得分: 0.0006
# 排名第98的供应商: S277, 综合评价得分: 0.0006
# 排名第99的供应商: S287, 综合评价得分: 0.0006
# 排名第100的供应商: S368, 综合评价得分: 0.0006
# 排名第101的供应商: S187, 综合评价得分: 0.0006
# 排名第102的供应商: S147, 综合评价得分: 0.0006
# 排名第103的供应商: S068, 综合评价得分: 0.0006
# 排名第104的供应商: S200, 综合评价得分: 0.0006
# 排名第105的供应商: S361, 综合评价得分: 0.0006
# 排名第106的供应商: S199, 综合评价得分: 0.0005
# 排名第107的供应商: S034, 综合评价得分: 0.0005
# 排名第108的供应商: S065, 综合评价得分: 0.0005
# 排名第109的供应商: S016, 综合评价得分: 0.0005
# 排名第110的供应商: S183, 综合评价得分: 0.0005
# 排名第111的供应商: S122, 综合评价得分: 0.0004
# 排名第112的供应商: S081, 综合评价得分: 0.0004
# 排名第113的供应商: S384, 综合评价得分: 0.0004
# 排名第114的供应商: S240, 综合评价得分: 0.0004
# 排名第115的供应商: S088, 综合评价得分: 0.0004
# 排名第116的供应商: S094, 综合评价得分: 0.0004
# 排名第117的供应商: S004, 综合评价得分: 0.0004
# 排名第118的供应商: S302, 综合评价得分: 0.0004
# 排名第119的供应商: S166, 综合评价得分: 0.0004
# 排名第120的供应商: S316, 综合评价得分: 0.0004
# 排名第121的供应商: S018, 综合评价得分: 0.0004
# 排名第122的供应商: S116, 综合评价得分: 0.0004
# 排名第123的供应商: S114, 综合评价得分: 0.0004
# 排名第124的供应商: S219, 综合评价得分: 0.0003
# 排名第125的供应商: S131, 综合评价得分: 0.0003
# 排名第126的供应商: S098, 综合评价得分: 0.0003
# 排名第127的供应商: S062, 综合评价得分: 0.0003
# 排名第128的供应商: S028, 综合评价得分: 0.0003
# 排名第129的供应商: S126, 综合评价得分: 0.0003
# 排名第130的供应商: S220, 综合评价得分: 0.0003
# 排名第131的供应商: S337, 综合评价得分: 0.0003
# 排名第132的供应商: S211, 综合评价得分: 0.0003
# 排名第133的供应商: S178, 综合评价得分: 0.0003
# 排名第134的供应商: S310, 综合评价得分: 0.0003
# 排名第135的供应商: S326, 综合评价得分: 0.0003
# 排名第136的供应商: S305, 综合评价得分: 0.0003
# 排名第137的供应商: S099, 综合评价得分: 0.0003
# 排名第138的供应商: S331, 综合评价得分: 0.0003
# 排名第139的供应商: S394, 综合评价得分: 0.0003
# 排名第140的供应商: S186, 综合评价得分: 0.0003
# 排名第141的供应商: S033, 综合评价得分: 0.0003
# 排名第142的供应商: S032, 综合评价得分: 0.0003
# 排名第143的供应商: S195, 综合评价得分: 0.0003
# 排名第144的供应商: S143, 综合评价得分: 0.0003
# 排名第145的供应商: S202, 综合评价得分: 0.0003
# 排名第146的供应商: S003, 综合评价得分: 0.0003
# 排名第147的供应商: S233, 综合评价得分: 0.0003
# 排名第148的供应商: S301, 综合评价得分: 0.0003
# 排名第149的供应商: S248, 综合评价得分: 0.0003
# 排名第150的供应商: S226, 综合评价得分: 0.0003
# 排名第151的供应商: S174, 综合评价得分: 0.0003
# 排名第152的供应商: S055, 综合评价得分: 0.0003
# 排名第153的供应商: S139, 综合评价得分: 0.0002
# 排名第154的供应商: S271, 综合评价得分: 0.0002
# 排名第155的供应商: S118, 综合评价得分: 0.0002
# 排名第156的供应商: S261, 综合评价得分: 0.0002
# 排名第157的供应商: S207, 综合评价得分: 0.0002
# 排名第158的供应商: S395, 综合评价得分: 0.0002
# 排名第159的供应商: S063, 综合评价得分: 0.0002
# 排名第160的供应商: S362, 综合评价得分: 0.0002
# 排名第161的供应商: S180, 综合评价得分: 0.0002
# 排名第162的供应商: S140, 综合评价得分: 0.0002
# 排名第163的供应商: S256, 综合评价得分: 0.0002
# 排名第164的供应商: S288, 综合评价得分: 0.0002
# 排名第165的供应商: S002, 综合评价得分: 0.0002
# 排名第166的供应商: S120, 综合评价得分: 0.0002
# 排名第167的供应商: S389, 综合评价得分: 0.0002
# 排名第168的供应商: S129, 综合评价得分: 0.0002
# 排名第169的供应商: S353, 综合评价得分: 0.0002
# 排名第170的供应商: S100, 综合评价得分: 0.0002
# 排名第171的供应商: S276, 综合评价得分: 0.0002
# 排名第172的供应商: S179, 综合评价得分: 0.0002
# 排名第173的供应商: S308, 综合评价得分: 0.0002
# 排名第174的供应商: S167, 综合评价得分: 0.0002
# 排名第175的供应商: S225, 综合评价得分: 0.0002
# 排名第176的供应商: S106, 综合评价得分: 0.0002
# 排名第177的供应商: S294, 综合评价得分: 0.0002
# 排名第178的供应商: S173, 综合评价得分: 0.0002
# 排名第179的供应商: S257, 综合评价得分: 0.0002
# 排名第180的供应商: S054, 综合评价得分: 0.0002
# 排名第181的供应商: S037, 综合评价得分: 0.0002
# 排名第182的供应商: S315, 综合评价得分: 0.0002
# 排名第183的供应商: S341, 综合评价得分: 0.0002
# 排名第184的供应商: S149, 综合评价得分: 0.0002
# 排名第185的供应商: S157, 综合评价得分: 0.0002
# 排名第186的供应商: S093, 综合评价得分: 0.0002
# 排名第187的供应商: S343, 综合评价得分: 0.0002
# 排名第188的供应商: S127, 综合评价得分: 0.0002
# 排名第189的供应商: S270, 综合评价得分: 0.0001
# 排名第190的供应商: S115, 综合评价得分: 0.0001
# 排名第191的供应商: S203, 综合评价得分: 0.0001
# 排名第192的供应商: S365, 综合评价得分: 0.0001
# 排名第193的供应商: S385, 综合评价得分: 0.0001
# 排名第194的供应商: S235, 综合评价得分: 0.0001
# 排名第195的供应商: S252, 综合评价得分: 0.0001
# 排名第196的供应商: S161, 综合评价得分: 0.0001
# 排名第197的供应商: S388, 综合评价得分: 0.0001
# 排名第198的供应商: S105, 综合评价得分: 0.0001
# 排名第199的供应商: S371, 综合评价得分: 0.0001
# 排名第200的供应商: S386, 综合评价得分: 0.0001
# 排名第201的供应商: S284, 综合评价得分: 0.0001
# 排名第202的供应商: S123, 综合评价得分: 0.0001
# 排名第203的供应商: S279, 综合评价得分: 0.0001
# 排名第204的供应商: S006, 综合评价得分: 0.0001
# 排名第205的供应商: S379, 综合评价得分: 0.0001
# 排名第206的供应商: S387, 综合评价得分: 0.0001
# 排名第207的供应商: S367, 综合评价得分: 0.0001
# 排名第208的供应商: S196, 综合评价得分: 0.0001
# 排名第209的供应商: S311, 综合评价得分: 0.0001
# 排名第210的供应商: S084, 综合评价得分: 0.0001
# 排名第211的供应商: S218, 综合评价得分: 0.0001
# 排名第212的供应商: S025, 综合评价得分: 0.0001
# 排名第213的供应商: S228, 综合评价得分: 0.0001
# 排名第214的供应商: S350, 综合评价得分: 0.0001
# 排名第215的供应商: S145, 综合评价得分: 0.0001
# 排名第216的供应商: S192, 综合评价得分: 0.0001
# 排名第217的供应商: S263, 综合评价得分: 0.0001
# 排名第218的供应商: S278, 综合评价得分: 0.0001
# 排名第219的供应商: S044, 综合评价得分: 0.0001
# 排名第220的供应商: S264, 综合评价得分: 0.0001
# 排名第221的供应商: S208, 综合评价得分: 0.0001
# 排名第222的供应商: S170, 综合评价得分: 0.0001
# 排名第223的供应商: S040, 综合评价得分: 0.0001
# 排名第224的供应商: S158, 综合评价得分: 0.0001
# 排名第225的供应商: S075, 综合评价得分: 0.0001
# 排名第226的供应商: S247, 综合评价得分: 0.0001
# 排名第227的供应商: S104, 综合评价得分: 0.0001
# 排名第228的供应商: S293, 综合评价得分: 0.0001
# 排名第229的供应商: S189, 综合评价得分: 0.0001
# 排名第230的供应商: S292, 综合评价得分: 0.0001
# 排名第231的供应商: S241, 综合评价得分: 0.0001
# 排名第232的供应商: S269, 综合评价得分: 0.0001
# 排名第233的供应商: S262, 综合评价得分: 0.0001
# 排名第234的供应商: S285, 综合评价得分: 0.0001
# 排名第235的供应商: S282, 综合评价得分: 0.0001
# 排名第236的供应商: S113, 综合评价得分: 0.0001
# 排名第237的供应商: S164, 综合评价得分: 0.0001
# 排名第238的供应商: S246, 综合评价得分: 0.0001
# 排名第239的供应商: S009, 综合评价得分: 0.0001
# 排名第240的供应商: S254, 综合评价得分: 0.0001
# 排名第241的供应商: S124, 综合评价得分: 0.0001
# 排名第242的供应商: S317, 综合评价得分: 0.0001
# 排名第243的供应商: S234, 综合评价得分: 0.0001
# 排名第244的供应商: S298, 综合评价得分: 0.0001
# 排名第245的供应商: S191, 综合评价得分: 0.0001
# 排名第246的供应商: S058, 综合评价得分: 0.0001
# 排名第247的供应商: S059, 综合评价得分: 0.0001
# 排名第248的供应商: S236, 综合评价得分: 0.0001
# 排名第249的供应商: S125, 综合评价得分: 0.0001
# 排名第250的供应商: S146, 综合评价得分: 0.0001
# 排名第251的供应商: S209, 综合评价得分: 0.0001
# 排名第252的供应商: S182, 综合评价得分: 0.0001
# 排名第253的供应商: S132, 综合评价得分: 0.0001
# 排名第254的供应商: S041, 综合评价得分: 0.0001
# 排名第255的供应商: S188, 综合评价得分: 0.0001
# 排名第256的供应商: S026, 综合评价得分: 0.0001
# 排名第257的供应商: S259, 综合评价得分: 0.0001
# 排名第258的供应商: S197, 综合评价得分: 0.0001
# 排名第259的供应商: S089, 综合评价得分: 0.0001
# 排名第260的供应商: S318, 综合评价得分: 0.0001
# 排名第261的供应商: S051, 综合评价得分: 0.0001
# 排名第262的供应商: S077, 综合评价得分: 0.0001
# 排名第263的供应商: S107, 综合评价得分: 0.0001
# 排名第264的供应商: S023, 综合评价得分: 0.0001
# 排名第265的供应商: S052, 综合评价得分: 0.0001
# 排名第266的供应商: S393, 综合评价得分: 0.0001
# 排名第267的供应商: S133, 综合评价得分: 0.0001
# 排名第268的供应商: S045, 综合评价得分: 0.0001
# 排名第269的供应商: S400, 综合评价得分: 0.0001
# 排名第270的供应商: S266, 综合评价得分: 0.0001
# 排名第271的供应商: S152, 综合评价得分: 0.0001
# 排名第272的供应商: S206, 综合评价得分: 0.0001
# 排名第273的供应商: S398, 综合评价得分: 0.0001
# 排名第274的供应商: S280, 综合评价得分: 0.0001
# 排名第275的供应商: S306, 综合评价得分: 0.0001
# 排名第276的供应商: S229, 综合评价得分: 0.0001
# 排名第277的供应商: S014, 综合评价得分: 0.0001
# 排名第278的供应商: S010, 综合评价得分: 0.0001
# 排名第279的供应商: S001, 综合评价得分: 0.0001
# 排名第280的供应商: S061, 综合评价得分: 0.0001
# 排名第281的供应商: S165, 综合评价得分: 0.0001
# 排名第282的供应商: S204, 综合评价得分: 0.0001
# 排名第283的供应商: S177, 综合评价得分: 0.0001
# 排名第284的供应商: S071, 综合评价得分: 0.0001
# 排名第285的供应商: S047, 综合评价得分: 0.0001
# 排名第286的供应商: S135, 综合评价得分: 0.0001
# 排名第287的供应商: S392, 综合评价得分: 0.0001
# 排名第288的供应商: S168, 综合评价得分: 0.0001
# 排名第289的供应商: S319, 综合评价得分: 0.0001
# 排名第290的供应商: S290, 综合评价得分: 0.0001
# 排名第291的供应商: S184, 综合评价得分: 0.0001
# 排名第292的供应商: S144, 综合评价得分: 0.0001
# 排名第293的供应商: S064, 综合评价得分: 0.0001
# 排名第294的供应商: S073, 综合评价得分: 0.0001
# 排名第295的供应商: S035, 综合评价得分: 0.0001
# 排名第296的供应商: S314, 综合评价得分: 0.0001
# 排名第297的供应商: S383, 综合评价得分: 0.0001
# 排名第298的供应商: S322, 综合评价得分: 0.0001
# 排名第299的供应商: S162, 综合评价得分: 0.0001
# 排名第300的供应商: S324, 综合评价得分: 0.0001
# 排名第301的供应商: S172, 综合评价得分: 0.0001
# 排名第302的供应商: S156, 综合评价得分: 0.0001
# 排名第303的供应商: S274, 综合评价得分: 0.0001
# 排名第304的供应商: S212, 综合评价得分: 0.0001
# 排名第305的供应商: S043, 综合评价得分: 0.0001
# 排名第306的供应商: S221, 综合评价得分: 0.0001
# 排名第307的供应商: S015, 综合评价得分: 0.0001
# 排名第308的供应商: S012, 综合评价得分: 0.0001
# 排名第309的供应商: S232, 综合评价得分: 0.0001
# 排名第310的供应商: S327, 综合评价得分: 0.0001
# 排名第311的供应商: S057, 综合评价得分: 0.0001
# 排名第312的供应商: S175, 综合评价得分: 0.0001
# 排名第313的供应商: S151, 综合评价得分: 0.0001
# 排名第314的供应商: S154, 综合评价得分: 0.0001
# 排名第315的供应商: S082, 综合评价得分: 0.0001
# 排名第316的供应商: S237, 综合评价得分: 0.0001
# 排名第317的供应商: S021, 综合评价得分: 0.0001
# 排名第318的供应商: S070, 综合评价得分: 0.0001
# 排名第319的供应商: S095, 综合评价得分: 0.0001
# 排名第320的供应商: S017, 综合评价得分: 0.0001
# 排名第321的供应商: S401, 综合评价得分: 0.0001
# 排名第322的供应商: S230, 综合评价得分: 0.0001
# 排名第323的供应商: S238, 综合评价得分: 0.0001
# 排名第324的供应商: S357, 综合评价得分: 0.0001
# 排名第325的供应商: S171, 综合评价得分: 0.0001
# 排名第326的供应商: S250, 综合评价得分: 0.0001
# 排名第327的供应商: S300, 综合评价得分: 0.0001
# 排名第328的供应商: S214, 综合评价得分: 0.0001
# 排名第329的供应商: S091, 综合评价得分: 0.0001
# 排名第330的供应商: S198, 综合评价得分: 0.0001
# 排名第331的供应商: S096, 综合评价得分: 0.0001
# 排名第332的供应商: S056, 综合评价得分: 0.0001
# 排名第333的供应商: S345, 综合评价得分: 0.0001
# 排名第334的供应商: S038, 综合评价得分: 0.0001
# 排名第335的供应商: S382, 综合评价得分: 0.0001
# 排名第336的供应商: S286, 综合评价得分: 0.0001
# 排名第337的供应商: S244, 综合评价得分: 0.0001
# 排名第338的供应商: S342, 综合评价得分: 0.0001
# 排名第339的供应商: S273, 综合评价得分: 0.0001
# 排名第340的供应商: S024, 综合评价得分: 0.0001
# 排名第341的供应商: S181, 综合评价得分: 0.0001
# 排名第342的供应商: S352, 综合评价得分: 0.0001
# 排名第343的供应商: S321, 综合评价得分: 0.0001
# 排名第344的供应商: S150, 综合评价得分: 0.0001
# 排名第345的供应商: S074, 综合评价得分: 0.0001
# 排名第346的供应商: S267, 综合评价得分: 0.0001
# 排名第347的供应商: S087, 综合评价得分: 0.0001
# 排名第348的供应商: S155, 综合评价得分: 0.0001
# 排名第349的供应商: S110, 综合评价得分: 0.0001
# 排名第350的供应商: S169, 综合评价得分: 0.0001
# 排名第351的供应商: S351, 综合评价得分: 0.0001
# 排名第352的供应商: S289, 综合评价得分: 0.0001
# 排名第353的供应商: S022, 综合评价得分: 0.0001
# 排名第354的供应商: S078, 综合评价得分: 0.0001
# 排名第355的供应商: S330, 综合评价得分: 0.0001
# 排名第356的供应商: S260, 综合评价得分: 0.0001
# 排名第357的供应商: S375, 综合评价得分: 0.0001
# 排名第358的供应商: S103, 综合评价得分: 0.0001
# 排名第359的供应商: S215, 综合评价得分: 0.0001
# 排名第360的供应商: S136, 综合评价得分: 0.0001
# 排名第361的供应商: S213, 综合评价得分: 0.0001
# 排名第362的供应商: S275, 综合评价得分: 0.0001
# 排名第363的供应商: S333, 综合评价得分: 0.0001
# 排名第364的供应商: S130, 综合评价得分: 0.0001
# 排名第365的供应商: S029, 综合评价得分: 0.0001
# 排名第366的供应商: S060, 综合评价得分: 0.0001
# 排名第367的供应商: S332, 综合评价得分: 0.0001
# 排名第368的供应商: S359, 综合评价得分: 0.0001
# 排名第369的供应商: S346, 综合评价得分: 0.0001
# 排名第370的供应商: S377, 综合评价得分: 0.0001
# 排名第371的供应商: S079, 综合评价得分: 0.0001
# 排名第372的供应商: S370, 综合评价得分: 0.0001
# 排名第373的供应商: S148, 综合评价得分: 0.0001
# 排名第374的供应商: S399, 综合评价得分: 0.0001
# 排名第375的供应商: S227, 综合评价得分: 0.0001
# 排名第376的供应商: S397, 综合评价得分: 0.0001
# 排名第377的供应商: S072, 综合评价得分: 0.0001
# 排名第378的供应商: S194, 综合评价得分: 0.0001
# 排名第379的供应商: S338, 综合评价得分: 0.0001
# 排名第380的供应商: S356, 综合评价得分: 0.0001
# 排名第381的供应商: S242, 综合评价得分: 0.0001
# 排名第382的供应商: S295, 综合评价得分: 0.0001
# 排名第383的供应商: S339, 综合评价得分: 0.0001
# 排名第384的供应商: S313, 综合评价得分: 0.0001
# 排名第385的供应商: S005, 综合评价得分: 0.0001
# 排名第386的供应商: S366, 综合评价得分: 0.0001
# 排名第387的供应商: S360, 综合评价得分: 0.0001
# 排名第388的供应商: S323, 综合评价得分: 0.0001
# 排名第389的供应商: S134, 综合评价得分: 0.0001
# 排名第390的供应商: S031, 综合评价得分: 0.0000
# 排名第391的供应商: S027, 综合评价得分: 0.0000
# 排名第392的供应商: S222, 综合评价得分: 0.0000
# 排名第393的供应商: S019, 综合评价得分: 0.0000
# 排名第394的供应商: S307, 综合评价得分: 0.0000
# 排名第395的供应商: S372, 综合评价得分: 0.0000
# 排名第396的供应商: S291, 综合评价得分: 0.0000
# 排名第397的供应商: S268, 综合评价得分: 0.0000
# 排名第398的供应商: S283, 综合评价得分: 0.0000
# 排名第399的供应商: S363, 综合评价得分: 0.0000
# 排名第400的供应商: S193, 综合评价得分: 0.0000
# 排名第401的供应商: S344, 综合评价得分: 0.0000
# 排名第402的供应商: S272, 综合评价得分: 0.0000
# C:\Users\海棠微雨\AppData\Local\Temp\ipykernel_25568\3818683643.py:3: RuntimeWarning: divide by zero encountered in log
#   E = -np.nansum(P * np.log(P), axis=0) / np.log(data.shape[0])
# C:\Users\海棠微雨\AppData\Local\Temp\ipykernel_25568\3818683643.py:3: RuntimeWarning: invalid value encountered in multiply
#   E = -np.nansum(P * np.log(P), axis=0) / np.log(data.shape[0])

# %%
# 创建DataFrame保存结果
result_df = pd.DataFrame({
    '由大到小综合评价的索引': indices
})

# 输出到Excel文件
output_path = r"C:/Users/海棠微雨/Desktop/cumcm2021c/C/由大到小综合评价的索引.xlsx"
result_df.to_excel(output_path, index=False)

print(f"由大到小综合评价的索引已保存到 {output_path}")
# Out:
# 由大到小综合评价的索引已保存到 C:/Users/海棠微雨/Desktop/cumcm2021c/C/由大到小综合评价的索引.xlsx

# %%
# 创建DataFrame保存结果
result_df = pd.DataFrame({
    '供应商': top_50_suppliers,
    '综合评价得分': top_50_scores
})

# 输出到Excel文件
output_path = r"C:/Users/海棠微雨/Desktop/cumcm2021c/C/供应商综合评价排名.xlsx"
result_df.to_excel(output_path, index=False)

print(f"排名前50的供应商及其综合评价得分已保存到 {output_path}")

# %%
from scipy.optimize import linprog

# %%
# 获取评分排名的结果
indices = np.argsort(scores)[::-1][:]
scores = scores[indices]
suppliers = suppliers[indices]

# 输出排名结果
for i, (supplier, score) in enumerate(zip(suppliers, scores)):
    print(f"排名第{i+1}的供应商: {supplier}, 综合评价得分: {score:.4f}")

# 提取按评分排序的供应商数据
df_sorted = df.iloc[indices]

# 提取A、B、C类材料的供货量数据
data_A = df_sorted[df_sorted['材料分类'] == 'A'].iloc[:, 2:].values
data_B = df_sorted[df_sorted['材料分类'] == 'B'].iloc[:, 2:].values
data_C = df_sorted[df_sorted['材料分类'] == 'C'].iloc[:, 2:].values

# 目标函数：最小化总供应商数量
c = np.ones(data_A.shape[0] + data_B.shape[0] + data_C.shape[0])

# 约束条件：x/0.6 + y/0.66 + z/0.72 >= 56400
A_ub = np.zeros((1, c.size))
A_ub[0, :data_A.shape[0]] = -1 / 0.6
A_ub[0, data_A.shape[0]:data_A.shape[0] + data_B.shape[0]] = -1 / 0.66
A_ub[0, data_A.shape[0] + data_B.shape[0]:] = -1 / 0.72
b_ub = [54200]

# 变量的取值范围
bounds = [(0, None) for _ in range(c.size)]

# 调用linprog函数求解
result = linprog(c, A_ub=A_ub, b_ub=b_ub, bounds=bounds, method='highs')

# 输出结果
if result.success:
    print("最优解：")
    for i, x in enumerate(result.x):
        if x > 0:
            if i < data_A.shape[0]:
                supplier = df_sorted[df_sorted['材料分类'] == 'A'].iloc[i, 0]
            elif i < data_A.shape[0] + data_B.shape[0]:
                supplier = df_sorted[df_sorted['材料分类'] == 'B'].iloc[i - data_A.shape[0], 0]
            else:
                supplier = df_sorted[df_sorted['材料分类'] == 'C'].iloc[i - data_A.shape[0] - data_B.shape[0], 0]
            print(f"{supplier}: {x:.2f} 立方米")
    print(f"满足需求的最小供应商数量 = {np.sum(result.x > 0)}")
else:
    print("没有找到最优解")

# %%
# top_50_suppliers
# df_top_50
data_A
